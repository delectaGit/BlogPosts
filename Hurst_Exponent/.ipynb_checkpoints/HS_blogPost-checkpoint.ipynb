# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import glob
import pickle as pkl
from scipy import stats
import random 
import time

# %%
import utility_funcs as uf

# %%
def hurst(p):
    # find variances for different sets of price differences:
    p = np.array(p)
    tau = np.arange(2,100)
    variancetau = [np.var(np.subtract(p[lag:], p[:-lag])) for lag in tau]

    # find the slope of the fitting line in the log-log plane:
    tau = np.log(tau)
    variancetau = np.log(variancetau)
    # find and remove mean:
    xb = np.mean(tau)
    yb = np.mean(variancetau)
    tau -= xb
    variancetau -= yb
    # find the slope:
    m = np.dot(tau, variancetau) / np.dot(tau, tau)

    return m / 2

# %%
def add_cur_name(df,cur_name):
    df["cur_name"] = cur_name
    print(cur_name,"done!")

def remove_old_days(df,yr='2018'):
    cond = df.Date > yr+"-01-01"
    df = df[cond].copy()
    return df
def func_collection(df,cur_name,yr="2018"):
    df = remove_old_days(df,yr)
    add_cur_name(df,cur_name)
    
    return df

# %%
def gaussian(x, mu, sig):
    return np.exp(-np.power(x - mu, 2.) / (2 * np.power(sig, 2.)))

# %%
def rnd_walk_simulator(sigma = 1, candle_bundle = 100, num_bundles = 200, initial = 1,\
                       generator = 'normal', seed = None):
    df = pd.DataFrame()
    close_var = initial     
    close_list = []
    np.random.seed(seed)
    for x in range(num_bundles):
        tick_data = []
        if generator == 'normal':
            rnd = np.random.normal(loc=0.0, scale=sigma, size = candle_bundle)
            close_var += np.sum(rnd)
        elif generator == 'uniform':
            rnd = np.random.uniform(low=0, high= 1, size = candle_bundle)
            close_var += np.sum((rnd - 0.5)*sigma)
        elif generator == 'poisson':
            rnd = np.random.poisson(lam = 1, size = candle_bundle)
            close_var += np.sum((rnd - 1)*sigma)
                     
        close_list.append(close_var)     
        
    df["close"] = close_list
    
    return df

# %%
file_list = glob.glob("./data/*")
file_dict = {}
file_to_remove = []
for f in file_list:
    pair = f.split("/")[-1][:-4]
        file_dict[f] = pair
        
print(file_list)
# Out:
# ['./data/NZD_CHF.csv', './data/GBP_USD.csv']

# %%
df = uf.read_many_files(file_list,add_to_each_df_func=lambda df,x: func_collection(df,x,yr="2017"),\
                        func_args=file_dict)

df = df.dropna(axis = 0)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-58494367321b> in <module>()
# ----> 1 df = uf.read_many_files(file_list,add_to_each_df_func=lambda df,x: func_collection(df,x,yr="2017"),                        func_args=file_dict)
#       2
#       3 df = df.dropna(axis = 0)
#       4 df.head()
#
# NameError: name 'file_dict' is not defined

# %%
cond = df.cur_name == "GBP_USD"
print(hurst(df[cond].close ))
df[cond].close.plot()

frame = plt.gca()
frame.axes.get_xaxis().set_ticks([])
frame.axes.get_yaxis().set_visible(False)
plt.xlabel('Example A',fontsize = 14)
# Out:
# 0.4920291157326661
# Text(0.5,0,'Example A')

# %%
cond = df.cur_name == "NZD_CHF"
print(hurst(df[cond].close))
df[cond].close.plot()

frame = plt.gca()
frame.axes.get_xaxis().set_ticks([])
frame.axes.get_yaxis().set_visible(False)
plt.xlabel('Example B',fontsize = 14)
# Out:
# 0.46623572958741655
# Text(0.5,0,'Example B')

# %%
df_rnd1 = rnd_walk_simulator(seed=10, sigma= 0.00005, num_bundles=300000)
print(hurst(df_rnd1.close))
df_rnd1.close.plot()

frame = plt.gca()
frame.axes.get_xaxis().set_ticks([])
frame.axes.get_yaxis().set_visible(False)
plt.xlabel('Example C',fontsize = 14)
# Out:
# 0.49815925500399966
# Text(0.5,0,'Example C')

# %%
df_rnd2 = rnd_walk_simulator(seed=100, sigma= 0.00005, num_bundles=300000)
print(hurst(df_rnd2.close))
df_rnd2.close.plot()

frame = plt.gca()
frame.axes.get_xaxis().set_ticks([])
frame.axes.get_yaxis().set_visible(False)
plt.xlabel('Example D',fontsize = 14)
# Out:
# 0.49433492766978543
# Text(0.5,0,'Example D')

# %% [markdown]
# # Hurst exponent for Forex market:
# ### For a nice post on Hurst exponent and its indications look at <a href = "http://epchan.blogspot.com/2016/04/mean-reversion-momentum-and-volatility.html">here</a>.

# %% [markdown]
# ## all data:

# %%
for pair in df.cur_name.unique():
    cond = df.cur_name == pair
    hs = hurst(df[cond].close)
    print("Hurst for %s is %.5f"%(pair,hs),end = ' , ')
    print("total len of the df is:",len(df[cond]))
# Out:
# Hurst for AUD_CAD is 0.47601 , total len of the df is: 347974
# Hurst for EUR_GBP is 0.48346 , total len of the df is: 335914
# Hurst for CAD_CHF is 0.47618 , total len of the df is: 345407
# Hurst for NZD_CHF is 0.46624 , total len of the df is: 346018
# Hurst for GBP_CHF is 0.47944 , total len of the df is: 347436
# Hurst for AUD_NZD is 0.47661 , total len of the df is: 347714
# Hurst for EUR_CHF is 0.46886 , total len of the df is: 330338
# Hurst for AUD_USD is 0.48186 , total len of the df is: 318705
# Hurst for NZD_USD is 0.47697 , total len of the df is: 342122
# Hurst for EUR_CAD is 0.48600 , total len of the df is: 348112
# Hurst for EUR_AUD is 0.48122 , total len of the df is: 339278
# Hurst for USD_CAD is 0.48610 , total len of the df is: 345049
# Hurst for AUD_JPY is 0.48484 , total len of the df is: 345311
# Hurst for GBP_CAD is 0.48966 , total len of the df is: 347509
# Hurst for GBP_JPY is 0.49259 , total len of the df is: 347164
# Hurst for NZD_JPY is 0.47907 , total len of the df is: 348119
# Hurst for NZD_CAD is 0.47937 , total len of the df is: 347841
# Hurst for USD_CHF is 0.47609 , total len of the df is: 323591
# Hurst for GBP_AUD is 0.48708 , total len of the df is: 347384
# Hurst for AUD_CHF is 0.47212 , total len of the df is: 340916
# Hurst for GBP_USD is 0.49203 , total len of the df is: 340473
# Hurst for CAD_JPY is 0.48685 , total len of the df is: 348119
# Hurst for EUR_USD is 0.48823 , total len of the df is: 340172
# Hurst for GBP_NZD is 0.48375 , total len of the df is: 347297
# Hurst for USD_JPY is 0.48630 , total len of the df is: 342418
# Hurst for CHF_JPY is 0.46961 , total len of the df is: 347949
# Hurst for EUR_NZD is 0.48029 , total len of the df is: 348025
# Hurst for EUR_JPY is 0.48696 , total len of the df is: 343327

# %% [markdown]
# ### Smaller chunks of data:

# %%
cur_list = df.cur_name.unique()
cur_list
# Out:
# array(['NZD_CHF', 'EUR_USD'], dtype=object)

# %%
windows = [5000,10000,50000,100000,200000]
total_hs_values = 5000 # total number of hurst values to get
for pair in cur_list:
    cond = (df.cur_name == pair)
    closes = df[cond].close
    for wd in windows:
        st_idx = wd + total_hs_values
        col_name = "hurst_" + str(wd//1000)
        df.loc[cond,col_name] = closes[-st_idx:].rolling(window = wd).apply(func = hurst)
    print(pair+" done!")
# Out:
# AUD_CAD done!
# NZD_CHF done!
# EUR_USD done!
# USD_JPY done!

# %%
for pair in df.cur_name.unique():
    cond = df.cur_name == pair
    c_diff = df[cond].close  - df[cond].close.shift(1)
    print(pair,c_diff.std(),c_diff.std()/np.sqrt(120))
# Out:
# AUD_CAD 0.000179434345214764 1.63800397442159e-05
# NZD_CHF 0.00015937238628954735 1.4548641835702024e-05
# EUR_USD 0.00020927532947043653 1.910413644671396e-05
# USD_JPY 0.0214294646379179 0.0019562335295744853

# %%
df.tail()
# Out:
#            index                Date     open     high      low    close  \
# 1075315  1084861 2018-11-14 00:48:00  113.892  113.906  113.887  113.906
# 1075316  1084862 2018-11-14 00:50:00  113.904  113.904  113.866  113.889
# 1075317  1084863 2018-11-14 00:52:00  113.887  113.926  113.887  113.922
# 1075318  1084864 2018-11-14 00:54:00  113.924  113.937  113.912  113.926
# 1075319  1084865 2018-11-14 00:56:00  113.924  113.941  113.910  113.914
#
#          volume cur_name   hurst_5
# 1075315      23  USD_JPY  0.446154
# 1075316      47  USD_JPY  0.446160
# 1075317      42  USD_JPY  0.446158
# 1075318      58  USD_JPY  0.446174
# 1075319      37  USD_JPY  0.446203

# %% [markdown]
# ## Random Walks:

# %% [markdown]
# ### rnd_steps = 1000:

# %%
hurst_li1 = []
c_diff_std = []
st = time.time()
for ii in range(10000):
    df_norm = rnd_walk_simulator(sigma =  0.002,\
                                 candle_bundle=1,\
                                 num_bundles = 1000,\
                                 seed = ii,\
                                 generator= 'normal')
    hs = hurst(df_norm.close.values)
    hurst_li1.append(hs)
    
    if ii%500 == 0:
        print("%d done, time= %.4f"%(ii,time.time()-st),end=", ")
        st = time.time()
# Out:
# 0 done, time= 0.0157, 500 done, time= 4.7522, 1000 done, time= 4.5451, 1500 done, time= 4.5710, 2000 done, time= 4.5727, 2500 done, time= 4.9420, 3000 done, time= 4.4295, 3500 done, time= 4.3842, 4000 done, time= 4.6229, 4500 done, time= 4.8607, 5000 done, time= 4.4074, 5500 done, time= 4.4067, 6000 done, time= 4.4743, 6500 done, time= 4.4095, 7000 done, time= 4.7841, 7500 done, time= 4.4094, 8000 done, time= 4.9857, 8500 done, time= 4.4390, 9000 done, time= 4.7254, 9500 done, time= 4.5974,

# %%
hurst_li1 = pkl.load(open("./hurst_li1.pkl","rb"))

# %%
plt.figure(figsize=(12,8))
print(np.mean(hurst_li1),np.std(hurst_li1) )
_ = plt.hist(hurst_li1,bins=25)

x_range = np.arange(0.2,0.7,0.005)
plt.plot(x_range, 1250*gaussian(x_range,np.mean(hurst_li1),np.std(hurst_li1)),'r')

plt.text(0.2,200,"Random-Walk Length = 1000",fontsize = 20)
plt.text(0.2,180,"mean = "+'{0:.4f}'.format(np.mean(hurst_li1)),fontsize = 20)
plt.text(0.2,160,"std = "+'{0:.4f}'.format(np.std(hurst_li1)),fontsize = 20)
plt.xlabel("Hurst Exponent",fontsize=18)
plt.ylabel("frequency",fontsize=18)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# Out:
# 0.47129958772364805 0.0634725846736031
# (array([   0.,  200.,  400.,  600.,  800., 1000., 1200., 1400.]),
#  <a list of 8 Text yticklabel objects>)

# %%
hurst_li1b = []
c_diff_std = []
st = time.time()
for ii in range(10000):
    df_norm = rnd_walk_simulator(sigma =  0.002,\
                                 candle_bundle=100,\
                                 num_bundles = 1000,\
                                 seed = ii,\
                                 generator= 'normal')
    hs = hurst(df_norm.close.values)
    hurst_li1b.append(hs)
    
    if ii%500 == 0:
        print("%d done, time= %.4f"%(ii,time.time()-st),end=", ")
        st = time.time()
# Out:
# 0 done, time= 0.0201, 500 done, time= 6.5539, 1000 done, time= 6.5826, 1500 done, time= 6.8260, 2000 done, time= 7.5078, 2500 done, time= 7.1038, 3000 done, time= 7.2931, 3500 done, time= 7.0199, 4000 done, time= 7.0717, 4500 done, time= 7.0502, 5000 done, time= 6.9520, 5500 done, time= 6.6266, 6000 done, time= 6.5877, 6500 done, time= 6.5909, 7000 done, time= 6.7807, 7500 done, time= 6.8224, 8000 done, time= 6.5639, 8500 done, time= 6.6475, 9000 done, time= 6.7635, 9500 done, time= 6.7385,

# %%
plt.figure(figsize=(12,8))
print(np.mean(hurst_li1b),np.std(hurst_li1b) )
_ = plt.hist(hurst_li1b,bins=25)
x_range = np.arange(0.2,0.7,0.005)
plt.plot(x_range, 1150*gaussian(x_range,np.mean(hurst_li1b),np.std(hurst_li1b)),'r')


plt.text(0.2,200,"Random-Walk Length = 1000",fontsize = 20)
plt.text(0.2,180,"mean = "+'{0:.4f}'.format(np.mean(hurst_li1b)),fontsize = 20)
plt.text(0.2,160,"std = "+'{0:.4f}'.format(np.std(hurst_li1b)),fontsize = 20)


plt.xlabel("Hurst Exponent",fontsize=18)
plt.ylabel("frequency",fontsize=18)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# Out:
# 0.4725404727514945 0.06364431394412635
# (array([   0.,  200.,  400.,  600.,  800., 1000., 1200., 1400.]),
#  <a list of 8 Text yticklabel objects>)

# %%
print(stats.skewtest(hurst_li1))
print(stats.kurtosistest(hurst_li1))
# Out:
# SkewtestResult(statistic=-6.871317258780966, pvalue=6.361174282491602e-12)
# KurtosistestResult(statistic=-0.47791802851137394, pvalue=0.6327085491085964)

# %%
print(stats.skewtest(hurst_li1b))
print(stats.kurtosistest(hurst_li1b))
# Out:
# SkewtestResult(statistic=-9.302589716701412, pvalue=1.3706575555830712e-20)
# KurtosistestResult(statistic=-0.1734695541390695, pvalue=0.8622823573381447)

# %%
pkl.dump(hurst_li1,open("./hurst_li1.pkl","wb"))

# %% [markdown]
# ### rnd_steps = 10000:

# %%
hurst_li10n = []
st = time.time()
for ii in range(10000):
    df_norm = rnd_walk_simulator(sigma =  0.002,\
                                 candle_bundle=1,\
                                 num_bundles = 10000,\
                                 seed = ii,\
                                 generator='normal')
    
    hs = hurst(df_norm.close.values)
    hurst_li10n.append(hs)
    if ii%500 == 0:
        print("%d done, time= %.4f"%(ii,time.time()-st),end=", ")
        st = time.time()
# Out:
# 0 done, time= 0.0962, 500 done, time= 34.9130, 1000 done, time= 33.4250, 1500 done, time= 33.4468, 2000 done, time= 33.3330, 2500 done, time= 33.3497, 3000 done, time= 33.4137, 3500 done, time= 33.3155, 4000 done, time= 33.4977, 4500 done, time= 33.4594, 5000 done, time= 33.7591, 5500 done, time= 33.3843, 6000 done, time= 33.4233, 6500 done, time= 33.3005, 7000 done, time= 33.3244, 7500 done, time= 34.0827, 8000 done, time= 33.7646, 8500 done, time= 34.2802, 9000 done, time= 33.2515, 9500 done, time= 33.5301,

# %%
pkl.dump(hurst_li10n,open("./hurst_li10_n.pkl","wb"))

# %%
plt.figure(figsize=(12,8))
print(np.mean(hurst_li10n),np.std(hurst_li10n) )
a = plt.hist(hurst_li10n,bins=30,normed=True)

x_range = np.arange(0.42,0.58,0.002)
amp = np.max(a[0])
plt.plot(x_range, amp*gaussian(x_range,np.mean(hurst_li10n),np.std(hurst_li10n)),'r')

plt.text(0.412,amp,"Random-Walk Length = 10000",fontsize = 20)
plt.text(0.412,amp-1.5,"mean = "+'{0:.4f}'.format(np.mean(hurst_li10n)),fontsize = 20)
plt.text(0.412,amp-3,"std = "+'{0:.4f}'.format(np.std(hurst_li10n)),fontsize = 20)
plt.xlabel("Hurst Exponent",fontsize=18)
plt.ylabel("frequency",fontsize=18)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.xlim(0.41,0.58)
# Out:
# 0.4973285518801711 0.019287160134145304
# (0.41, 0.58)

# %%
print(stats.skewtest(hurst_li10n))
print(stats.kurtosistest(hurst_li10n))
print(stats.shapiro(hurst_li10n))
# Out:
# SkewtestResult(statistic=-2.293142070092994, pvalue=0.02183982700036346)
# KurtosistestResult(statistic=2.14806702304602, pvalue=0.03170843148085946)
# (0.9994485378265381, 0.003426923183724284)
# /home/alimina/anaconda3/lib/python3.6/site-packages/scipy/stats/morestats.py:1326: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %%
hurst_li10u10 = []
st = time.time()
for ii in range(10000):
    df_norm = rnd_walk_simulator(sigma =  0.002,\
                                 candle_bundle=10,\
                                 num_bundles = 10000,\
                                 seed = ii,\
                                 generator='uniform')
    
    hs = hurst(df_norm.close.values)
    hurst_li10u10.append(hs)
    if ii%500 == 0:
        print("%d done, time= %.4f"%(ii,time.time()-st),end=", ")
        st = time.time()
# Out:
# 0 done, time= 0.1120, 500 done, time= 40.8012, 1000 done, time= 44.1301, 1500 done, time= 38.5427, 2000 done, time= 38.5571, 2500 done, time= 38.5196, 3000 done, time= 38.6177, 3500 done, time= 38.3794, 4000 done, time= 38.5717, 4500 done, time= 38.7238, 5000 done, time= 39.0597, 5500 done, time= 38.6700, 6000 done, time= 38.6927, 6500 done, time= 38.5257, 7000 done, time= 38.6471, 7500 done, time= 38.5731, 8000 done, time= 38.6990, 8500 done, time= 38.5980, 9000 done, time= 38.7695, 9500 done, time= 39.1387,

# %%
print(stats.skewtest(hurst_li10u10))
print(stats.kurtosistest(hurst_li10u10))
print(stats.shapiro(hurst_li10u10))
# Out:
# SkewtestResult(statistic=-3.4345604583952936, pvalue=0.0005935156597206448)
# KurtosistestResult(statistic=0.6350859904510229, pvalue=0.5253723335481211)
# (0.9993918538093567, 0.001508395653218031)
# /home/alimina/anaconda3/lib/python3.6/site-packages/scipy/stats/morestats.py:1326: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %%
hurst_li10u = []
st = time.time()
for ii in range(10000):
    df_norm = rnd_walk_simulator(sigma =  0.002,\
                                 candle_bundle=1,\
                                 num_bundles = 10000,\
                                 seed = ii,\
                                 generator='uniform')
    
    hs = hurst(df_norm.close.values)
    hurst_li10u.append(hs)
    if ii%500 == 0:
        print("%d done, time= %.4f"%(ii,time.time()-st),end=", ")
        st = time.time()
# Out:
# 0 done, time= 0.1095, 500 done, time= 42.9416, 1000 done, time= 43.0851, 1500 done, time= 39.1965, 2000 done, time= 39.0544, 2500 done, time= 39.1885, 3000 done, time= 38.9128, 3500 done, time= 38.9099, 4000 done, time= 38.9808, 4500 done, time= 38.8322, 5000 done, time= 39.4153, 5500 done, time= 38.7849, 6000 done, time= 38.5917, 6500 done, time= 38.7031, 7000 done, time= 38.5378, 7500 done, time= 38.5613, 8000 done, time= 38.5767, 8500 done, time= 38.5169, 9000 done, time= 38.4373, 9500 done, time= 38.6781,

# %%
pkl.dump(hurst_li10u,open("./hurst_li10_u.pkl","wb"))

# %%
plt.figure(figsize=(12,8))
print(np.mean(hurst_li10u),np.std(hurst_li10u) )
a = plt.hist(hurst_li10u,bins=25,normed=True)

x_range = np.arange(0.42,0.58,0.002)
amp = np.max(a[0])
plt.plot(x_range, amp*gaussian(x_range,np.mean(hurst_li10u),np.std(hurst_li10u)),'r')

plt.text(0.412,amp,"Random-Walk Length = 10000",fontsize = 19)
plt.text(0.412,amp-1.5,"mean = "+'{0:.4f}'.format(np.mean(hurst_li10u)),fontsize = 19)
plt.text(0.412,amp-3,"std = "+'{0:.4f}'.format(np.std(hurst_li10u)),fontsize = 19)
plt.xlabel("Hurst Exponent",fontsize=18)
plt.ylabel("frequency",fontsize=18)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.xlim(0.41,0.58)
# Out:
# 0.4975865490974271 0.01920499738172972
# (0.41, 0.58)

# %%
print(stats.skewtest(hurst_li10u))
print(stats.kurtosistest(hurst_li10u))
print(stats.shapiro(hurst_li10u))
# Out:
# SkewtestResult(statistic=-3.298838240130921, pvalue=0.000970858388868575)
# KurtosistestResult(statistic=-0.08445209056631714, pvalue=0.9326969928882204)
# (0.9994351267814636, 0.002817050786688924)
# /home/alimina/anaconda3/lib/python3.6/site-packages/scipy/stats/morestats.py:1326: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %%
hurst_li10p = []
st = time.time()
for ii in range(10000):
    df_norm = rnd_walk_simulator(sigma =  0.002,\
                                 candle_bundle=1,\
                                 num_bundles = 10000,\
                                 seed = ii,\
                                 generator='poisson')
    
    hs = hurst(df_norm.close.values)
    hurst_li10p.append(hs)
    if ii%500 == 0:
        print("%d done, time= %.4f"%(ii,time.time()-st),end=", ")
        st = time.time()
# Out:
# 0 done, time= 0.1370, 500 done, time= 42.1722, 1000 done, time= 43.8220, 1500 done, time= 42.4492, 2000 done, time= 42.4437, 2500 done, time= 42.3429, 3000 done, time= 43.9027, 3500 done, time= 42.2558, 4000 done, time= 42.3798, 4500 done, time= 42.1131, 5000 done, time= 42.0931, 5500 done, time= 42.0448, 6000 done, time= 42.1390, 6500 done, time= 42.2498, 7000 done, time= 42.1194, 7500 done, time= 42.1572, 8000 done, time= 42.3313, 8500 done, time= 42.5118, 9000 done, time= 42.0514, 9500 done, time= 42.1852,

# %%
pkl.dump(hurst_li10p,open("./hurst_li10_p.pkl","wb"))

# %%
plt.figure(figsize=(12,8))
print(np.mean(hurst_li10p),np.std(hurst_li10p) )
a = plt.hist(hurst_li10p,bins=25,normed=True)

x_range = np.arange(0.42,0.58,0.002)
amp = np.max(a[0])
plt.plot(x_range, amp*gaussian(x_range,np.mean(hurst_li10p),np.std(hurst_li10p)),'r')

plt.text(0.412,amp,"Random-Walk Length = 10000",fontsize = 19)
plt.text(0.412,amp-1.5,"mean = "+'{0:.4f}'.format(np.mean(hurst_li10p)),fontsize = 19)
plt.text(0.412,amp-3,"std = "+'{0:.4f}'.format(np.std(hurst_li10p)),fontsize = 19)
plt.xlabel("Hurst Exponent",fontsize=18)
plt.ylabel("frequency",fontsize=18)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.xlim(0.41,0.58)
# Out:
# 0.49761077945781906 0.019397083706689088
# (0.41, 0.58)

# %%
print(stats.skewtest(hurst_li10p))
print(stats.kurtosistest(hurst_li10p))
print(stats.shapiro(hurst_li10p))
# Out:
# SkewtestResult(statistic=-2.0553737079549013, pvalue=0.03984292297697105)
# KurtosistestResult(statistic=-0.9300669015530841, pvalue=0.35233644654683316)
# (0.9995974898338318, 0.03136578947305679)
# /home/alimina/anaconda3/lib/python3.6/site-packages/scipy/stats/morestats.py:1326: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %% [markdown]
# ### rnd_steps = 100000:

# %%
hurst_li100 = []
st = time.time()
for ii in range(10000):
    df_norm = rnd_walk_simulator(sigma =  0.002,\
                                 candle_bundle=1,\
                                 num_bundles = 100000,\
                                 seed = ii,\
                                 generator='normal')
    
    hs = hurst(df_norm.close.values)
    hurst_li100.append(hs)
    if ii%500 == 0:
        print("%d done, time= %.4f"%(ii,time.time()-st),end=", ")
        st = time.time()
# Out:
# 0 done, time= 0.6589, 500 done, time= 360.5264, 1000 done, time= 369.0569, 1500 done, time= 381.9417, 2000 done, time= 375.6941, 2500 done, time= 352.2228, 3000 done, time= 360.5117, 3500 done, time= 377.1919, 4000 done, time= 382.5946, 4500 done, time= 347.6013, 5000 done, time= 344.6007, 5500 done, time= 346.9138, 6000 done, time= 352.7429, 6500 done, time= 353.7730, 7000 done, time= 350.1097, 7500 done, time= 351.7248, 8000 done, time= 348.2312, 8500 done, time= 349.3438, 9000 done, time= 350.8850, 9500 done, time= 351.5927,

# %%
hurst_li100 = pkl.load(open("./hurst_li100.pkl","rb"))

# %%
plt.figure(figsize=(12,8))
print(np.mean(hurst_li100),np.std(hurst_li100) )
a = plt.hist(hurst_li100,bins=30,normed=True)

x_range = np.arange(0.47,0.53,0.0005)
amp = np.max(a[0])
plt.plot(x_range, amp*gaussian(x_range,np.mean(hurst_li100),np.std(hurst_li100)),'r')

plt.text(0.4755,amp,"Random-Walk Length = 100000",fontsize = 20)
plt.text(0.4755,amp-5,"mean = "+'{0:.4f}'.format(np.mean(hurst_li100)),fontsize = 20)
plt.text(0.4755,amp-10,"std = "+'{0:.4f}'.format(np.std(hurst_li100)),fontsize = 20)
plt.xlabel("Hurst Exponent",fontsize=18)
plt.ylabel("frequency",fontsize=18)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.xlim(0.475,0.525)
# Out:
# 0.4996890151279655 0.0060831918456582465
# (0.475, 0.525)

# %%
print(stats.skewtest(hurst_li100))
print(stats.kurtosistest(hurst_li100))
print(stats.shapiro(hurst_li100))
# Out:
# SkewtestResult(statistic=-0.9407508050564959, pvalue=0.3468325766925271)
# KurtosistestResult(statistic=0.08275248961566271, pvalue=0.9340483472830842)
# (0.999830961227417, 0.6778658032417297)
# /home/alimina/anaconda3/lib/python3.6/site-packages/scipy/stats/morestats.py:1326: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %%
print(stats.skew(hurst_li100))
print(stats.kurtosis(hurst_li100))
# Out:
# -0.023029401278034163
# 0.0022576095483266556

# %%
pkl.dump(hurst_li100,open("./hurst_li100.pkl","wb"))

# %%
hurst_li100u = []
st = time.time()
for ii in range(10000):
    df_norm = rnd_walk_simulator(sigma =  0.002,\
                                 candle_bundle=1,\
                                 num_bundles = 100000,\
                                 seed = ii,\
                                 generator='uniform')
    
    hs = hurst(df_norm.close.values)
    hurst_li100u.append(hs)
    if ii%500 == 0:
        print("%d done, time= %.4f"%(ii,time.time()-st),end=", ")
        st = time.time()
# Out:
# 0 done, time= 0.7648, 500 done, time= 3415.9947, 1000 done, time= 367.2228, 1500 done, time= 366.4329, 2000 done, time= 367.1245, 2500 done, time= 368.8297, 3000 done, time= 370.5546, 3500 done, time= 369.9341, 4000 done, time= 371.6526, 4500 done, time= 416.5966, 5000 done, time= 465.9186, 5500 done, time= 436.6161, 6000 done, time= 445.7589, 6500 done, time= 445.5698, 7000 done, time= 443.8797, 7500 done, time= 425.7276, 8000 done, time= 427.9445, 8500 done, time= 419.9981, 9000 done, time= 388.9699, 9500 done, time= 384.5860,

# %%
plt.figure(figsize=(12,8))
print(np.mean(hurst_li100u),np.std(hurst_li100u) )
a = plt.hist(hurst_li100u,bins=30,normed=True)

x_range = np.arange(0.47,0.53,0.0005)
amp = np.max(a[0])
plt.plot(x_range, amp*gaussian(x_range,np.mean(hurst_li100u),np.std(hurst_li100u)),'r')

plt.text(0.4755,amp,"Random-Walk Length = 10000",fontsize = 20)
plt.text(0.4755,amp-5,"mean = "+'{0:.4f}'.format(np.mean(hurst_li100u)),fontsize = 20)
plt.text(0.4755,amp-10,"std = "+'{0:.4f}'.format(np.std(hurst_li100u)),fontsize = 20)
plt.xlabel("Hurst Exponent",fontsize=18)
plt.ylabel("frequency",fontsize=18)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.xlim(0.475,0.525)
# Out:
# 0.49970485614083465 0.006022231078746345
# (0.475, 0.525)

# %%
print(stats.skewtest(hurst_li100u))
print(stats.kurtosistest(hurst_li100u))
print(stats.shapiro(hurst_li100u))
# Out:
# SkewtestResult(statistic=-2.82688738545128, pvalue=0.004700285429534236)
# KurtosistestResult(statistic=1.462823896095707, pvalue=0.1435155725930291)
# (0.999565064907074, 0.01929362490773201)
# /home/alimina/anaconda3/lib/python3.6/site-packages/scipy/stats/morestats.py:1326: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %%
pkl.dump(hurst_li100u,open("./hurst_li100u.pkl","wb"))

# %% [markdown]
# ###  rnd_steps = 300000:

# %%
hurst_li300 = []
st = time.time()
for ii in range(1000):
    df_norm = rnd_walk_simulator(sigma =  0.002,\
                                 num_bundles = 300000,\
                                 seed = ii)
    
    hs = hurst(df_norm.close.values)
    hurst_li300.append(hs)
    if ii%100 == 0:
        print("%d done, time= %.4f"%(ii,time.time()-st),end=", ")
        st = time.time()
# Out:
# 0 done, time= 3.3026, 100 done, time= 363.5886, 200 done, time= 370.8800, 300 done, time= 344.2197, 400 done, time= 349.9841, 500 done, time= 354.0914, 600 done, time= 339.4433, 700 done, time= 325.0656, 800 done, time= 344.1690, 900 done, time= 332.2664,

# %%
hurst_li300 = pkl.load(open("./hurst_li300.pkl","rb"))

# %%
plt.figure(figsize=(12,8))
print(np.mean(hurst_li300),np.std(hurst_li300) )
_ = plt.hist(hurst_li300,bins=12)

plt.text(0.486,200,"Random-Walk Length = 300000",fontsize = 15)
plt.text(0.486,180,"mean = "+'{0:.4f}'.format(np.mean(hurst_li300)),fontsize = 15)
plt.text(0.486,160,"std = "+'{0:.4f}'.format(np.std(hurst_li300)),fontsize = 15)
plt.xlabel("Hurst Exponent",fontsize=14)
plt.ylabel("frequency",fontsize=14)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
# Out:
# 0.4996838765361534 0.003520648542656769
# (array([  0.,  50., 100., 150., 200., 250.]),
#  <a list of 6 Text yticklabel objects>)

# %%
pkl.dump(hurst_li300,open("./hurst_li300.pkl","wb"))

# %%
print(stats.norm(loc=0.5, scale=0.0034).cdf(0.49203)*2) # two sided 
print(stats.norm(loc=0.5, scale=0.0034).cdf(0.46624)*2) # two sided 
print(stats.norm(loc=0.5, scale=0.0034).cdf(0.49816)*2) # two sided 
print(stats.norm(loc=0.5, scale=0.0034).cdf(0.49433)*2) # two sided
# Out:
# 0.01907215437920434
# 3.100793472542805e-23
# 0.5883859538085674
# 0.09538581063395803

# %%
df_norm = rnd_walk_simulator(sigma =  0.0002, candle_bundle = 2 * 60,\
                             num_bundles = 300000, initial = 1)

# %%
df_norm.close.plot()

# %%
def hurst2(p):
    # find variances for different sets of price differences:
    p = np.array(p)
    tau = np.arange(2,200)
    variancetau = [np.var(np.subtract(p[lag:], p[:-lag])) for lag in tau]

    # find the slope of the fitting line in the log-log plane:
    tau = np.log(tau)
    variancetau = np.log(variancetau)
    # find and remove mean:
    xb = np.mean(tau)
    yb = np.mean(variancetau)
    tau -= xb
    variancetau -= yb
    # find the slope:
    m = np.dot(tau, variancetau) / np.dot(tau, tau)
    
#     plt.plot(tau+xb,variancetau,"*")
    plt.plot(tau+xb,m*tau - variancetau)
    plt.axhline(y=0,color='r')

    return m / 2

# %%
plt.figure(figsize=(12,8))
hurst2(df_norm.close)
# Out:
# 0.5001892377014476

# %%
plt.figure(figsize=(12,8))
cur_name = "NZD_CHF"
print(cur_name)
hurst2(df[df.cur_name == cur_name].close)
# Out:
# NZD_CHF
# 0.46623572958741655

# %%
plt.figure(figsize=(12,8))
cur_name = "EUR_USD"
print(cur_name)
hurst2(df[df.cur_name == cur_name].close)
# Out:
# EUR_USD
# 0.48823162211813687

# %%
plt.figure(figsize=(12,8))
cur_name = "EUR_GBP"
print(cur_name)
hurst2(df[df.cur_name == cur_name].close)
# Out:
# EUR_GBP
# 0.4834614316089862

# %%
plt.figure(figsize=(12,8))
cur_name = "USD_CAD"
print(cur_name)
hurst2(df[df.cur_name == cur_name].close)
# Out:
# USD_CAD
# 0.4860984708269855

# %%
plt.figure(figsize=(12,8))
cur_name = "USD_JPY"
print(cur_name)
hurst2(df[df.cur_name == cur_name].close)
# Out:
# USD_JPY
# 0.486298484446361

# %%
plt.figure(figsize=(12,8))
cur_name = "GBP_JPY"
print(cur_name)
hurst2(df[df.cur_name == cur_name].close)
# Out:
# GBP_JPY
# 0.4925916438210893

# %%
plt.figure(figsize=(12,8))
cur_name = "AUD_NZD"
print(cur_name)
hurst2(df[df.cur_name == cur_name].close)
# Out:
# AUD_NZD
# 0.4766093606777011

# %%
plt.figure(figsize=(12,8))
for ii in range(28):
    df_norm = rnd_walk_simulator(sigma =  0.0002, candle_bundle = 2 * 60,\
                                 num_bundles = 300000, initial = 1)
    hurst2(df_norm.close)

# %%
plt.figure(figsize=(12,8))
for cur_name in df.cur_name.unique():
    hurst2(df[df.cur_name == cur_name].close)

# %%
for cur_name in df.cur_name.unique():
    if cur_name[-3:] != 'JPY':
        m  = hurst2(df[df.cur_name == cur_name].close)
        print(cur_name,m)
        plt.show()
# Out:
# AUD_CAD 0.4771201205050668
# EUR_GBP 0.4874699600384558
# CAD_CHF 0.4786345631157362
# NZD_CHF 0.47334431175726766
# GBP_CHF 0.4840384012663077
# AUD_NZD 0.48407947296783554
# EUR_CHF 0.47059587981303214
# AUD_USD 0.48457317544077405
# NZD_USD 0.48297457465531274
# EUR_CAD 0.4875812823767669
# EUR_AUD 0.48543249427601487
# USD_CAD 0.48715615259328054
# GBP_CAD 0.49007533314605317
# NZD_CAD 0.4830455956693972
# USD_CHF 0.47938839668768135
# GBP_AUD 0.49220891896548785
# AUD_CHF 0.4782485969350008
# GBP_USD 0.4958645255854828
# EUR_USD 0.49166377715458004
# GBP_NZD 0.4879063676385256
# EUR_NZD 0.4840541853918073

# %%
plt.figure(figsize=(12,8))
for cur_name in df.cur_name.unique():
    if cur_name[-3:] != 'JPY':
        hurst2(df[df.cur_name == cur_name].close)

# %%
plt.figure(figsize=(12,8))
for cur_name in df.cur_name.unique():
    if cur_name[-3:] == 'JPY':
        hurst2(df[df.cur_name == cur_name].close)
